# %%
ml = 0
cl = 0
b = "|----B|"
mr = 3
cr = 3
flag = 0
print(" ".join(["M =", str(ml), "C =", str(cl), b, "M =", str(mr), "C =", str(cr)]))

while(True):
    
   # boat check
    while(True):
        mb = int(input("Enter the number of Missionaries to step on the boat: "))
        cb = int(input("Enter the number of Cannibals to step on the boat: "))
        
        if(mb+cb > 2 or mb+cb==0 or (flag==0 and (mb>mr or cb>cr)) or (flag==1 and (mb>ml or cb>cl)) or (mb<0 or cb<0)):
            print("Invalid move")
        else:
            break 
    
    if(flag==0): #boat will move to left
        ml+=mb
        cl+=cb
        mr-=mb
        cr-=cb
        flag = 1
        b = "|B----|"
        
    else:        #boat will move to right
        ml-=mb
        cl-=cb
        mr+=mb
        cr+=cb
        flag = 0
        b = "|----B|"
    
    if((ml!=0 and ml<cl) or (mr!=0 and mr<cr)):
        
        print("Oops you lose! Try again!")
        break
    else:
        print(" ".join(["M =", str(ml), "C =", str(cl), b, "M =", str(mr), "C =", str(cr)]))
        
    if(ml==3 and cl==3 and mr==0 and cr==0):
        print("Congrats! You Win")
        break
# Out:
# M = 0 C = 0 |----B| M = 3 C = 3
# Enter the number of Missionaries to step on the boat: 1
# Enter the number of Cannibals to step on the boat: 1
# M = 1 C = 1 |B----| M = 2 C = 2
# Enter the number of Missionaries to step on the boat: 1
# Enter the number of Cannibals to step on the boat: 0
# M = 0 C = 1 |----B| M = 3 C = 2

# %%
ml = 0
cl = 0
mr = 3
cr = 3
boat_side = 'Right'

print(" ".join(["M =", str(ml), "C =", str(cl) +" |----B| " + "M =", str(mr), "C =", str(cr)]))





while True: 
    
    mb = int(input("Enter the number of Missionaries to step on the boat: "))
    cb = int(input("Enter the number of Cannibals to step on the boat: "))
    
    
    if (mb + cb) > 2 or (mb+cb) < 1:
        print('Invalid Move..')
        continue 
    
    if boat_side =='Right':
            if (mr < mb) or (cr<cb):
                print('Invalid Move...')
                continue
                
            ml+=mb
            cl+=cb
            mr-=mb
            cr-=cb
            
            
            print(" ".join(["M =", str(ml), "C =", str(cl) +" |B----| " + "M =", str(mr), "C =", str(cr)]))
            
            boat_side = 'Left'
            
            
    elif boat== "Left":
            if (ml < mb) or (cl < cb):
                print('Invalid Move...')
                continue
                
            mr+=mb
            cr+=cb
            ml-=mb
            cl-=cb
            
            print(" ".join(["M =", str(ml), "C =", str(cl) +" |----B| " + "M =", str(mr), "C =", str(cr)]))
            
            boat_side = 'Right'
        
    if((ml!=0 and ml<cl) or (mr!=0 and mr<cr)):
        print("Oops you lose! Try again!")
        break

    if(ml==3 and cl==3 and mr==0 and cr==0):
        print("Congrats! You Win")
        break
# Out:
# M = 0 C = 0 |----B| M = 3 C = 3
# Enter the number of Missionaries to step on the boat: 1
# Enter the number of Cannibals to step on the boat: 1
# M = 1 C = 1 |B----| M = 2 C = 2
# Enter the number of Missionaries to step on the boat: 1
# Enter the number of Cannibals to step on the boat: 0
# Enter the number of Missionaries to step on the boat: 1
# Enter the number of Cannibals to step on the boat: 0
# Enter the number of Missionaries to step on the boat: 1
# Enter the number of Cannibals to step on the boat: 0
# Enter the number of Missionaries to step on the boat:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-77ba7ba01007> in <module>
#      13 while True:
#      14
# ---> 15     mb = int(input("Enter the number of Missionaries to step on the boat: "))
#      16     cb = int(input("Enter the number of Cannibals to step on the boat: "))
#      17
#
# ...
